# %% [markdown]
# <h1>Project: UK ACCIDENTS DATA ANALYTICS PROJECT</h1>

# %% [markdown]
# ---

# %% [markdown]
# <h2>Analyst: Jamaica Palas</h2>

# %% [markdown]
# ---

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>Converting Datasets to Dataframes</h1>

# %% [markdown]
# ---

# %%
accident = pd.read_csv("Datasets\\accident_data.csv")

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05/06/2019  51.506187
# 1       200701BS65737           Serious    02/07/2019  51.495029
# 2       200701BS66127           Serious    26/08/2019  51.517715
# 3       200701BS66128           Serious    16/08/2019  51.495478
# 4       200701BS66837            Slight    03/09/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18/02/2022  57.374005
# 660675  201091NM01881            Slight    21/02/2022  57.232273
# 660676  201091NM01935            Slight    23/02/2022  57.585044
# 660677  201091NM01964           Serious    23/02/2022  57.214898
# 660678  201091NM02142           Serious    28/02/2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
#  13  Vehicle_Type             660679 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.6+ MB

# %% [markdown]
# ---

# %% [markdown]
# <h1>CHECKING FOR NULL VALUES</h1>

# %% [markdown]
# ---

# %%
accident.isnull()
# Out:
#         Index  Accident_Severity  Accident Date  Latitude  Light_Conditions  \
# 0       False              False          False     False             False
# 1       False              False          False     False             False
# 2       False              False          False     False             False
# 3       False              False          False     False             False
# 4       False              False          False     False             False
# ...       ...                ...            ...       ...               ...
# 660674  False              False          False     False             False
# 660675  False              False          False     False             False
# 660676  False              False          False     False             False
# 660677  False              False          False     False             False
# 660678  False              False          False     False             False
#
#         District Area  Longitude  Number_of_Casualties  Number_of_Vehicles  \
# 0               False      False                 False               False
# 1               False      False                 False               False
# 2               False      False                 False               False
# 3               False      False                 False               False
# 4               False      False                 False               False
# ...               ...        ...                   ...                 ...
# 660674          False      False                 False               False
# 660675          False      False                 False               False
# 660676          False      False                 False               False
# 660677          False      False                 False               False
# 660678          False      False                 False               False
#
#         Road_Surface_Conditions  Road_Type  Urban_or_Rural_Area  \
# 0                         False      False                False
# 1                         False      False                False
# 2                         False       True                False
# 3                         False      False                False
# 4                         False       True                False
# ...                         ...        ...                  ...
# 660674                    False      False                False
# 660675                    False      False                False
# 660676                    False      False                False
# 660677                    False      False                False
# 660678                    False      False                False
#
#         Weather_Conditions  Vehicle_Type
# 0                    False         False
# 1                    False         False
# 2                     True         False
# 3                    False         False
# 4                     True         False
# ...                    ...           ...
# 660674               False         False
# 660675               False         False
# 660676               False         False
# 660677               False         False
# 660678               False         False
#
# [660679 rows x 14 columns]

# %% [markdown]
# <h1>SUMMARIZING NULL  VALUES</h1>

# %% [markdown]
# ---

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h1>Filling Null Values</h1>

# %% [markdown]
# ---

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mode()[0])
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mode()[0])
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].astype(str).fillna('unaccounted')
accident['Road_Type'] = accident['Road_Type'].astype(str).fillna('unaccounted')
accident['Weather_Conditions'] = accident['Weather_Conditions'].astype(str).fillna('unaccounted')
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.month
accident['Day'] = accident['Accident Date'].dt.day
accident['DayOfWeek'] = accident['Accident Date'].dt.dayofweek

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# Year                       0
# Month                      0
# Day                        0
# DayOfWeek                  0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# <h1>Adjusting Data types</h1>

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident['Accident_Severity'] = accident['Accident_Severity'].astype('category')
accident['Light_Conditions'] = accident['Light_Conditions'].astype('category')
accident['District Area'] = accident['District Area'].astype('category')
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].astype('category')
accident['Road_Type'] = accident['Road_Type'].astype('category')
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].astype('category')
accident['Weather_Conditions'] = accident['Weather_Conditions'].astype('category')
accident['Vehicle_Type'] = accident['Vehicle_Type'].astype('category')
accident['Accident Date'] = accident['Accident Date'].astype('str')
accident['Accident Date'] = accident['Accident Date'].str.replace('/','-')
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %% [markdown]
# ---

# %% [markdown]
# <h1>QUESTIONS</h1?

# %% [markdown]
# ---

# %% [markdown]
# <h1>Q1: How many accidents are there by severity?</h1>

# %%
accident["Accident_Severity"].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHT: Most accidents fall into the "Slight" category, showing that extreme cases are relatively rare.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Q2: What is the most common weather condition during accidents?</h1>

# %%
accident["Weather_Conditions"].value_counts().idxmax()
# Out:
# 'Fine no high winds'

# %% [markdown]
# <h2>INSIGHT: Clear weather conditions dominate, suggesting that accidents are more linked to human error than bad weather.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Q3: Which light condition has the highest number of accidents?</h1>

# %%
accident["Light_Conditions"].value_counts()
# Out:
# Light_Conditions
# Daylight                       484880
# Darkness - lights lit          129335
# Darkness - no lighting          37437
# Darkness - lighting unknown      6484
# Darkness - lights unlit          2543
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHT: Daylight conditions account for more crashes, likely due to higher traffic volume during the day.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Q4: Which road surface condition is most common in accidents?</h1>

# %%
accident["Road_Surface_Conditions"].value_counts()
# Out:
# Road_Surface_Conditions
# Dry                     448547
# Wet or damp             186708
# Frost or ice             18517
# Snow                      5890
# Flood over 3cm. deep      1017
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHT: Dry roads are the most frequent, indicating that slippery surfaces aren’t the only risk factor.</h2>

# %% [markdown]
# <h1>Q5: What is the most common vehicle type involved in accidents?</h1>

# %%
accident["Vehicle_Type"].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h2>INSIGHT: Cars appear most often, which aligns with their dominance on the roads.</h2>

# %% [markdown]
# <h1>Q6: What is the mean number of casualties per accident?</h1>

# %%
accident["Number_of_Casualties"].mean()
# Out:
# np.float64(1.357040257068864)

# %% [markdown]
# <h2>INSIGHT: The average accident results in about 1–2 casualties, showing most incidents are not mass-casualty events.</h2>

# %% [markdown]
# <h1>Q7: What is the median number of casualties per accident?</h1>

# %%
accident["Number_of_Casualties"].median()
# Out:
# np.float64(1.0)

# %% [markdown]
# <h2>INSIGHT: The midpoint confirms that most accidents involve just one casualty.</h2>

# %% [markdown]
# <h1>Q8: What is the maximum number of casualties in one accident?</h1>

# %%
accident["Number_of_Casualties"].max()
# Out:
# np.int64(68)

# %% [markdown]
# <h2>INSIGHT: Extreme cases exist, but they are rare compared to the average accident.</h2>

# %% [markdown]
# <h1>Q9: What is the minimum number of casualties recorded?</h1>

# %%
accident["Number_of_Casualties"].min()
# Out:
# np.int64(1)

# %% [markdown]
# <h2>INSIGHT: The minimum casualty count shows that not all accidents result in injuries.</h2>

# %% [markdown]
# <h1>Q10: What is the average number of vehicles by road type?</h1>

# %%
accident.groupby("Road_Type")["Number_of_Vehicles"].mean()
# Out:
# Road_Type
# Dual carriageway      2.009766
# One way street        1.585441
# Roundabout            1.901323
# Single carriageway    1.795911
# Slip road             1.917483
# Unknown               1.674115
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# <h2>INSIGHT: Larger roads tend to involve more vehicles in accidents.</h2>

# %% [markdown]
# <h1>Q11: How many accidents happened each year?</h1>

# %%
accident_per_year = accident["Year"].value_counts().sort_index()

accident_per_year.plot(kind="bar", figsize=(6,4))
plt.title("Number of Accidents per Year")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h2>INSIGHT: You can describe whether accidents increased, decreased, or stayed the same over the years.</h2>

# %% [markdown]
# <h1>Q12: What is the trend of accidents over time (yearly)?</h1>

# %%
accidents_trend = accident.groupby('Year').size()

plt.figure(figsize=(8,5))
plt.plot(accidents_trend.index, accidents_trend.values, marker='o')
plt.title("Accident Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h2>Insight: Accidents go up or down, showing safety or traffic changes.</h2>

# %% [markdown]
# <h1>Q13: How does accident severity differ between urban and rural areas?</h1>

# %%
severity_by_area = accident.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts().unstack()

severity_by_area.plot(kind='bar', figsize=(8,5))
plt.title("Severity in Urban vs Rural Areas")
plt.xlabel("Area")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Rural accidents may be less frequent but more deadly.</h2>

# %% [markdown]
# <h1>Q14: How does accident severity vary by vehicle type involved?</h1>

# %%
severity_by_vehicle = accident.groupby('Vehicle_Type')['Accident_Severity'].value_counts().unstack()

severity_by_vehicle.plot(kind='bar', figsize=(12,6))
plt.title("Severity by Vehicle Type")
plt.xlabel("Vehicle Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Cars cause most accidents, but motorcycles tend to be more severe.</h2>

# %% [markdown]
# <h1>Q15: How does accident frequency vary by month?</h1>

# %%
month_counts = accident['Month'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.bar(month_counts.index, month_counts.values)
plt.title("Accidents by Month")
plt.xlabel("Month")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Summer and winter months tend to peak in accidents.</h2>

# %% [markdown]
# <h1>Q16: Accidents per day of week, broken down by severity.</h1>

# %%
accident_day_severity = accident.groupby(["DayOfWeek","Accident_Severity"]).size().unstack()
accident_day_severity.plot(kind="bar", figsize=(10,5))
plt.title("Accidents per Day of Week by Severity")
plt.xlabel("Day of Week")
plt.ylabel("Accidents")
plt.legend(title="Severity")
plt.show()

# %% [markdown]
# <h2>Insight: Shows if severe accidents are more frequent on weekends or weekdays.</h2>

# %% [markdown]
# <h1>Q17: Accidents per month, broken down by severity.</h1>

# %%
accident_month_severity = accident.groupby(["Month","Accident_Severity"]).size().unstack()
accident_month_severity.plot(kind="bar", figsize=(10,5))
plt.title("Accidents per Month by Severity")
plt.xlabel("Month")
plt.ylabel("Accidents")
plt.legend(title="Severity")
plt.show()

# %% [markdown]
# <h2>Insight: Reveals if severe accidents cluster in specific months.</h2>

# %% [markdown]
# <h1>Q18: Accidents per weather condition each year.</h1>

# %%
accident_weather_year = accident.groupby(["Year","Weather_Conditions"]).size().unstack()
accident_weather_year.plot(kind="bar", figsize=(10,5))
plt.title("Accidents per Weather Condition by Year")
plt.xlabel("Year")
plt.ylabel("Accidents")
plt.legend(title="Weather")
plt.show()

# %% [markdown]
# <h2>Insight: Shows if rainy, foggy, or clear weather impacts accident numbers.</h2>

# %% [markdown]
# <h1>Q19:How do accidents change by year?</h1>

# %%
accident.groupby("Year").size().plot( marker="o")
plt.title("Accidents per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Shows if accidents are rising, falling, or stable over the years.</h2>

# %% [markdown]
# <h1>Q20: How does accident severity vary by month?</h1>

# %%
accident.groupby(["Month","Accident_Severity"]).size().unstack().plot(kind="bar", stacked=True)
plt.title("Accident Severity by Month")
plt.xlabel("Month")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Certain months may have more severe crashes.</h2>

# %% [markdown]
# <h1>Q21: How do accidents spread across months for each year?</h1>

# %%
accident.groupby(["Year","Month"]).size().unstack().T.plot(kind="line", marker="o")
plt.title("Monthly Accidents by Year")
plt.xlabel("Month")
plt.ylabel("Accidents")
plt.show()

# %% [markdown]
# <h2>Insight: Highlights seasonal trends across years.</h2>

# %% [markdown]
# <h1>Q22: Do severe accidents occur more in rural or urban areas?</h1>

# %%
accident.groupby(["Urban_or_Rural_Area","Accident_Severity"]).size().unstack().plot(kind="bar")
plt.title("Severity by Area (Urban vs Rural)")
plt.xlabel("Area")
plt.ylabel("Accidents")
plt.show()

# %% [markdown]
# <h2>Insight: Shows whether rural roads are deadlier.</h2>

# %% [markdown]
# <h1>Q23: What is the average number of casualties per accident each year?</h1>

# %%
accident.groupby("Year")["Number_of_Casualties"].mean().plot(marker="o")
plt.title("Avg Casualties per Accident by Year")
plt.xlabel("Year")
plt.ylabel("Avg Casualties")
plt.show()

# %% [markdown]
# <h2>Insight: Shows if accidents are becoming deadlier or safer.</h2>

# %% [markdown]
# <h1>Q24: How does accident severity vary across different weather conditions?</h1>

# %%
severity_by_weather = accident.groupby('Weather_Conditions')['Accident_Severity'].value_counts().unstack()

severity_by_weather.plot(kind='bar', figsize=(10,5))
plt.title("Severity by Weather Conditions")
plt.xlabel("Weather Condition")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>Insight: Severe crashes are more common in rain, snow, and fog.</h2>

# %% [markdown]
# <h1>Q25: What is the average casualties per accident by month and light condition?</h1>

# %%
avg_cas_month_light = accident.groupby(["Month","Light_Conditions"])["Number_of_Casualties"].mean().unstack()
avg_cas_month_light.plot(marker="o")
plt.title("Avg Casualties by Month & Light Condition")
plt.xlabel("Month")
plt.ylabel("Avg Casualties")
plt.show()

# %% [markdown]
# <h2>Insight: Dark winter months often have worse casualty averages.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Monthly Road Accidents in 6 Selected Districts by Year (2019–2022)</h1>

# %%
city = 'Birmingham'
city_df = accident[accident['District Area'] == city]

monthly_city = city_df.groupby(['Year', 'Month']).size().unstack(level=0)

monthly_city.plot(marker='o', figsize=(10,5),
                  title=f"Monthly Road Accidents in {city} by Year (2019–2022)")
plt.xticks(range(1,13),
           ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.legend(title='Year')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h2>Insight 26: Birmingham shows a steady seasonal pattern, with slightly higher accident counts in warmer months.</h2>

# %%
city = 'Manchester'
city_df = accident[accident['District Area'] == city]

monthly_city = city_df.groupby(['Year', 'Month']).size().unstack(level=0)

monthly_city.plot(kind='bar', figsize=(12,6), colormap='tab10', width=0.8,
                  title=f"Monthly Road Accidents in {city} by Year (2019–2022)")
plt.xticks(range(0,12),
           ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
           rotation=0)
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.legend(title='Year')
plt.grid(alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <h1> Accidents Through the Year and Week in Top Districts</h1>

# %% [markdown]
# ---

# %%
weekday_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# %% [markdown]
# <h1>Birmingham: “Monthly and Weekday Road Accident Trends in Birmingham (2019–2022)</h1>

# %%
birmingham = accident[accident['District Area'] == 'Birmingham']
monthly = birmingham.groupby(['Year','Month']).size().unstack(level=0)

monthly.plot(marker='o', figsize=(10,5),
             title='Monthly Road Accidents in Birmingham (2019–2022)')
plt.xticks(range(1,13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# <h2>Insight 26: Accidents peak in autumn and winter (Oct–Dec) and drop in early spring, with a clear dip in 2020 due to pandemic restrictions.
# They occur most often on Fridays and Mondays, suggesting a need for weekday rush hour safety measures.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Leeds: “Monthly and Weekday Road Accident Trends in Leeds (2019–2022)”</h1>

# %%
import matplotlib.pyplot as plt

leeds = accident[accident['District Area'] == 'Leeds']
monthly = leeds.groupby(['Year','Month']).size().unstack(level=0)

monthly.plot(kind='bar', figsize=(12,5),
             title='Monthly Road Accidents in Leeds (2019–2022)')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=0)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("Leeds: Accidents rise in late-year months (Oct–Dec) and dipped in 2020 before recovering.")
print("They are most frequent from Wednesday to Friday, highlighting commuter traffic as a key factor.")
# Out:
# Leeds: Accidents rise in late-year months (Oct–Dec) and dipped in 2020 before recovering.
# They are most frequent from Wednesday to Friday, highlighting commuter traffic as a key factor.

# %% [markdown]
# <h2>Insight 27:Accidents rise in late-year months (Oct–Dec) and dipped in 2020 before recovering.
# They are most frequent from Wednesday to Friday, highlighting commuter traffic as a key factor.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Manchester: “Monthly and Weekday Road Accident Trends in Manchester (2019–2022)”</h1>

# %%
manchester = accident[accident['District Area'] == 'Manchester']
monthly = manchester.groupby(['Year','Month']).size().unstack(level=0)

# Vertical bar plot (stacked)
monthly.plot(kind='bar', figsize=(12,6), stacked=True, colormap='tab20',
             title='Monthly Road Accidents in Manchester (2019–2022)')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=0)
plt.grid(alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

print("Manchester: Accidents rise toward the end of the year, dropped sharply in 2020, and returned to normal afterward.")
# Out:
# Manchester: Accidents rise toward the end of the year, dropped sharply in 2020, and returned to normal afterward.

# %% [markdown]
# <h2>Insight 28: Accidents increase toward the end of the year and fell sharply in 2020 before returning to normal levels.
# They peak on Fridays and Saturdays, likely due to commuter and nightlife traffic.</h2

# %% [markdown]
# ---

# %% [markdown]
# <h1>Bradford: “Monthly and Weekday Road Accident Trends in Bradford (2019–2022)”</h1>

# %%
bradford = accident[accident['District Area'] == 'Bradford']
monthly = bradford.groupby(['Year','Month']).size().unstack(level=0)

monthly.plot(kind='barh', figsize=(10,6),
             title='Monthly Road Accidents in Bradford (2019–2022)')
plt.xlabel('Number of Accidents')
plt.ylabel('Month')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("Bradford: Accidents rise during autumn and winter and dropped in 2020 during lockdown.")
print("They cluster around mid-week and Fridays, reflecting commuter and school traffic patterns.")
# Out:
# Bradford: Accidents rise during autumn and winter and dropped in 2020 during lockdown.
# They cluster around mid-week and Fridays, reflecting commuter and school traffic patterns.

# %% [markdown]
# <h1>Insight 29: Accidents rise during autumn and winter and dropped in 2020 during lockdown.
# They cluster around mid-week and Fridays, reflecting commuter and school traffic patterns.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Sheffield: “Monthly and Weekday Road Accident Trends in Sheffield (2019–2022)”</h1>

# %%
sheffield = accident[accident['District Area'] == 'Sheffield']
monthly = sheffield.groupby(['Year','Month']).size().unstack(level=0)

monthly.plot(marker='o', figsize=(10,5),
             title='Monthly Road Accidents in Sheffield (2019–2022)')
plt.xticks(range(1,13), ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.grid(alpha=0.3)
plt.show()

print("Sheffield: Accidents are highest in colder months and dipped in 2020, then recovered afterward.")
print("Fridays and mid-week days show higher accident counts, linked to commuter rush hours.")
# Out:
# Sheffield: Accidents are highest in colder months and dipped in 2020, then recovered afterward.
# Fridays and mid-week days show higher accident counts, linked to commuter rush hours.

# %% [markdown]
# <h2>Insight 30: Accidents are highest in the colder months and dipped in 2020, then recovered afterward.
# Fridays and mid-week days show higher accident counts, linked to commuter rush hours.</h2>

# %% [markdown]
# ---

# %% [markdown]
# <h1>Westminster: “Monthly and Weekday Road Accident Trends in Westminster (2019–2022)”</h1>

# %%
westminster = accident[accident['District Area'] == 'Westminster']

yearly = westminster.groupby('Year').size()

plt.figure(figsize=(8,8))
plt.pie(yearly, labels=yearly.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99','#ffcc99','#ff9999'])
plt.title('Proportion of Road Accidents in Westminster by Year (2019–2022)')
plt.tight_layout()
plt.show()

print("Westminster: Most accidents occurred in 2019 and 2022, with a drop in 2020 likely due to reduced traffic during lockdowns.")
# Out:
# Westminster: Most accidents occurred in 2019 and 2022, with a drop in 2020 likely due to reduced traffic during lockdowns.

# %% [markdown]
# <h2>Insight 31:Most road accidents in Westminster occurred in 2019 and 2022, while 2020 saw a sharp drop due to COVID-19 restrictions. This highlights how traffic volume and external factors strongly affect accident rates</h2>
